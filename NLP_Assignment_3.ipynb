# %%
pip install gensim matplotlib scikit-learn

# %%
import numpy as np
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
words = ['king', 'queen', 'man', 'woman', 'paris', 'france', 'london', 'england']
corpus = [
    ['king', 'queen', 'man', 'woman'],
        ['paris', 'france', 'london', 'england'],
            ['king', 'man', 'queen', 'woman'],
                ['london', 'paris', 'france', 'england']
                ]
model = Word2Vec(corpus, vector_size=100, window=2, min_count=1, workers=4)
word_vectors = np.array([model.wv[word] for word in words])
pca = PCA(n_components=2)
reduced_vectors = pca.fit_transform(word_vectors)

plt.figure(figsize=(10, 6))
for i, word in enumerate(words):
      plt.scatter(reduced_vectors[i, 0], reduced_vectors[i, 1])
plt.annotate(word, (reduced_vectors[i, 0], reduced_vectors[i, 1]), textcoords="offset points", xytext=(0, 5), ha='center')

plt.title('Word Embeddings Visualized with PCA')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.grid()
plt.show()

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "The quick brown fox jumps over the lazy dog"
doc = nlp(text)

# Print the dependency parsing results
for token in doc:
    print(f'Text: {token.text}, Dependency: {token.dep_}, Head: {token.head.text}')
# Out:
# Text: The, Dependency: det, Head: fox
# Text: quick, Dependency: amod, Head: fox
# Text: brown, Dependency: amod, Head: fox
# Text: fox, Dependency: nsubj, Head: jumps
# Text: jumps, Dependency: ROOT, Head: jumps
# Text: over, Dependency: prep, Head: jumps
# Text: the, Dependency: det, Head: dog
# Text: lazy, Dependency: amod, Head: dog
# Text: dog, Dependency: pobj, Head: over
