# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %%
data = [("hello", "bonjour"),
        ("how are you", "comment ça va"),
        ("I am fine", "je vais bien"),
        ("what is your name", "comment tu t'appelles"),
        ("my name is", "je m'appelle"),
        ("thank you", "merci"),
        ("goodbye", "au revoir")]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np


english_sentences = [pair[0] for pair in data]
french_sentences = [pair[1] for pair in data]
eng_tokenizer = Tokenizer()
fre_tokenizer = Tokenizer()
eng_tokenizer.fit_on_texts(english_sentences)
fre_tokenizer.fit_on_texts(french_sentences)
eng_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
fre_sequences = fre_tokenizer.texts_to_sequences(french_sentences)
max_eng_len = max([len(seq) for seq in eng_sequences])
max_fre_len = max([len(seq) for seq in fre_sequences])

eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fre_padded = pad_sequences(fre_sequences, maxlen=max_fre_len, padding='post')


input_data = np.array(eng_padded)
output_data = np.array(fre_padded)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense


embedding_dim = 64
latent_dim = 128


encoder_inputs = Input(shape=(max_eng_len,))
encoder_embedding = Embedding(input_dim=len(eng_tokenizer.word_index) + 1, output_dim=embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)


decoder_inputs = Input(shape=(max_fre_len,))
decoder_embedding = Embedding(input_dim=len(fre_tokenizer.word_index) + 1, output_dim=embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])
decoder_dense = Dense(len(fre_tokenizer.word_index) + 1, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)


model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
fre_target_data = np.zeros_like(output_data)
fre_target_data[:, :-1] = output_data[:, 1:]
fre_target_data[:, -1] = 0
model.fit([input_data, output_data], fre_target_data, batch_size=16, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0000e+00 - loss: 2.6375 - val_accuracy: 0.8333 - val_loss: 2.6156
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5333 - loss: 2.6215 - val_accuracy: 0.8333 - val_loss: 2.5934
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5333 - loss: 2.6050 - val_accuracy: 0.8333 - val_loss: 2.5695
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5333 - loss: 2.5875 - val_accuracy: 0.8333 - val_loss: 2.5428
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 2.5682 - val_accuracy: 0.8333 - val_loss: 2.5125
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5333 - loss: 2.5464 - val_accuracy: 0.8333 - val_loss: 2.4773
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5333 - loss: 2.5215 - val_accuracy: 0.8333 - val_loss: 2.4362
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5333 - loss: 2.4926 - val_accuracy: 0.8333 - val_loss: 2.3876
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5333 - loss: 2.4588 - val_accuracy: 0.8333 - val_loss: 2.3298
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5333 - loss: 2.4189 - val_accuracy: 0.8333 - val_loss: 2.2610
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5333 - loss: 2.3717 - val_accuracy: 0.8333 - val_loss: 2.1786
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5333 - loss: 2.3155 - val_accuracy: 0.8333 - val_loss: 2.0802
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5333 - loss: 2.2487 - val_accuracy: 0.8333 - val_loss: 1.9628
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5333 - loss: 2.1694 - val_accuracy: 0.8333 - val_loss: 1.8239
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5333 - loss: 2.0761 - val_accuracy: 0.8333 - val_loss: 1.6620
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5333 - loss: 1.9683 - val_accuracy: 0.8333 - val_loss: 1.4796
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5333 - loss: 1.8485 - val_accuracy: 0.8333 - val_loss: 1.2867
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5333 - loss: 1.7242 - val_accuracy: 0.8333 - val_loss: 1.1045
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5333 - loss: 1.6105 - val_accuracy: 0.8333 - val_loss: 0.9619
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5333 - loss: 1.5292 - val_accuracy: 0.8333 - val_loss: 0.8811
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5333 - loss: 1.5005 - val_accuracy: 0.8333 - val_loss: 0.8613
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.5199 - val_accuracy: 0.8333 - val_loss: 0.8771
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5333 - loss: 1.5520 - val_accuracy: 0.8333 - val_loss: 0.8997
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8000 - loss: 0.5176 - val_accuracy: 0.8333 - val_loss: 2.0002
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8000 - loss: 0.4920 - val_accuracy: 0.8333 - val_loss: 2.0525
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8000 - loss: 0.4674 - val_accuracy: 0.8333 - val_loss: 2.1026
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8667 - loss: 0.4437 - val_accuracy: 0.8333 - val_loss: 2.1506
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8667 - loss: 0.4208 - val_accuracy: 0.8333 - val_loss: 2.1967
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8667 - loss: 0.3987 - val_accuracy: 0.8333 - val_loss: 2.2414
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8667 - loss: 0.3776 - val_accuracy: 0.8333 - val_loss: 2.2851
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.3573 - val_accuracy: 0.8333 - val_loss: 2.3279
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.3378 - val_accuracy: 0.8333 - val_loss: 2.3701
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.3187 - val_accuracy: 0.8333 - val_loss: 2.4114
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.3003 - val_accuracy: 0.8333 - val_loss: 2.4515
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.2827 - val_accuracy: 0.8333 - val_loss: 2.4900
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.2660 - val_accuracy: 0.8333 - val_loss: 2.5265
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.2501 - val_accuracy: 0.8333 - val_loss: 2.5606
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.2349 - val_accuracy: 0.8333 - val_loss: 2.5925
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2204 - val_accuracy: 0.8333 - val_loss: 2.6224
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.2067 - val_accuracy: 0.8333 - val_loss: 2.6506
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.1938 - val_accuracy: 0.6667 - val_loss: 2.6775
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.1815 - val_accuracy: 0.6667 - val_loss: 2.7034
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.1697 - val_accuracy: 0.6667 - val_loss: 2.7281
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.1585 - val_accuracy: 0.6667 - val_loss: 2.7514
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.1479 - val_accuracy: 0.6667 - val_loss: 2.7728
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.1378 - val_accuracy: 0.6667 - val_loss: 2.7920
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.1285 - val_accuracy: 0.6667 - val_loss: 2.8090
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.1198 - val_accuracy: 0.6667 - val_loss: 2.8238
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.1118 - val_accuracy: 0.6667 - val_loss: 2.8369
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.1044 - val_accuracy: 0.6667 - val_loss: 2.8486
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0976 - val_accuracy: 0.6667 - val_loss: 2.8595
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0914 - val_accuracy: 0.6667 - val_loss: 2.8695
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0856 - val_accuracy: 0.6667 - val_loss: 2.8790
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0803 - val_accuracy: 0.6667 - val_loss: 2.8877
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.0754 - val_accuracy: 0.6667 - val_loss: 2.8955
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0709 - val_accuracy: 0.6667 - val_loss: 2.9025

# %%
encoder_model = Model(encoder_inputs, [state_h, state_c])
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_inputs_single = Input(shape=(1,))
decoder_embedding_inference = Embedding(input_dim=len(fre_tokenizer.word_index) + 1, output_dim=embedding_dim)
decoder_inputs_single_x = decoder_embedding_inference(decoder_inputs_single)
decoder_outputs_single, state_h_dec, state_c_dec = decoder_lstm(decoder_inputs_single_x, initial_state=[decoder_state_input_h, decoder_state_input_c])
decoder_outputs_single = decoder_dense(decoder_outputs_single)
decoder_model = Model([decoder_inputs_single, decoder_state_input_h, decoder_state_input_c],
                      [decoder_outputs_single, state_h_dec, state_c_dec])

# %%
def translate_sentence(input_seq):
    states_value = encoder_model.predict(input_seq)
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fre_tokenizer.word_index['bonjour']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = None
        for word, index in fre_tokenizer.word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        if sampled_word is None or sampled_word == '<end>':
            stop_condition = True
        else:
            decoded_sentence += ' ' + sampled_word

        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index
        states_value = [h, c]

    return decoded_sentence.strip()
test_sentence = "how are you"
test_seq = eng_tokenizer.texts_to_sequences([test_sentence])
test_seq_padded = pad_sequences(test_seq, maxlen=max_eng_len, padding='post')
translation = translate_sentence(test_seq_padded)
print("Translation:", translation)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Translation: ça
